# %%
# %load_ext autoreload
# %autoreload 2

# %%
import common
import config

# %%
df = common.read_pickle_dict(config.INPUT_ORG_CLASS_PKL, config.INPUT_ORG_COLS)
df = common.replace_json_normalize(df, "classification", prefix="org_c_")
df.head()
# Out:
#                                    uuid          ip_str  port  \
# 0  00ff3296-7ff9-4ad6-bb5e-efabfd524358  15.228.228.116    80
# 1  800d4c75-932d-4a3a-a2cc-76ff96d42e57   177.8.224.246  8008
# 2  6646931c-5932-48fa-82c3-e15774452463   20.206.79.104  8443
# 3  85a7d6b1-a8cc-484e-948a-ed53866b6bb9     45.162.64.7  8080
# 4  909f6801-bcaf-4dec-ba0d-7336783d2164  179.42.135.197    80
#
#                                        org  \
# 0                                GUARANITO
# 1       RouterOS router configuration page
# 2                                  Service
# 3                              OoklaServer
# 4  P.F DE ANDRADE PROVEDOR DE INTERNET -ME
#
#                                  orgname  org_c_cloud_computing  \
# 0            Amazon Data Services Brazil               0.825724
# 1              ITS TELECOMUNICACOES LTDA               0.009528
# 2                  Microsoft Corporation               0.300166
# 3                    SEVEN INTERNET LTDA               0.327077
# ...
